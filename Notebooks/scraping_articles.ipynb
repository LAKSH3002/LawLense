# %% [markdown]
# This Scraping is Manual, with each link provided and data extracted for each link

# %%
# scrape_articles.py
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# Main HTML entities to be noticed while scraping constitution articles (documents) are:
# 1) h2 class = doc_title : Title of the document (articles)
# 2) section class = akn-section: The full section of the article
# 3) section class = akn-subsection: The sub sections of the full section

# %%
def scrape_constitution_article(url):
    """Scrape a constitution article page from Indian Kanoon."""
    # getting responses
    response = requests.get(url)
    if response.status_code != 200:
        print(f"❌ Failed to access {url}")
        return None

    # extracting html based text from the url
    soup = BeautifulSoup(response.text, "html.parser")

    # Extracting doc_title and main section from the document page, not search page.
    title = soup.find("h2", class_="doc_title")
    if title:
        title = title.get_text(strip=True)
    else:
        title = "No title found"

    # Extracting main section : section class="akn-section"
    main_section = soup.find("section", class_="akn-section")
    sections_data = []

    # Extracting sub section: section class="akn-subsection"
    if main_section:
        subsections = main_section.find_all("section", class_="akn-subsection")
        for sub in subsections:
            text = sub.get_text(separator=" ", strip=True)
            if not text or text.strip() == "":
                text = "Not Available"
                sections_data.append(text)
            else:
                sections_data.append(text)
    else:
        print(f"⚠️ No section found for {url}")

    return {
        "url": url,
        "title": title,
        "content": " ".join(sections_data)
    }

# %%
# Manually adding 25 articles data from the website and then scraping desired details
article_urls = [
    "https://indiankanoon.org/doc/367586/", # Article 14
    "https://indiankanoon.org/doc/609295/", # Article 15
    "https://indiankanoon.org/doc/211089/", # Article 16
    "https://indiankanoon.org/doc/1987997/", # Article 17
    "https://indiankanoon.org/doc/1163710/", # Article 18
    "https://indiankanoon.org/doc/1218090/", # Article 19
    "https://indiankanoon.org/doc/655638/" , # Article 20
    "https://indiankanoon.org/doc/1199182/", # Article 21
    "https://indiankanoon.org/doc/581566/",  # Artcle 22
    "https://indiankanoon.org/doc/1071750/", # Article 23
    "https://indiankanoon.org/doc/1540780/", # Article 24
    "https://indiankanoon.org/doc/631708/", # Article 25
    "https://indiankanoon.org/doc/1858991/", # Article 26
    "https://indiankanoon.org/doc/211413/", # Article 27
    "https://indiankanoon.org/doc/1734560/", # Article 28
    "https://indiankanoon.org/doc/1734560/", # Article 29
    "https://indiankanoon.org/doc/1983234/", # Article 30
    "https://indiankanoon.org/doc/354224/", # Article 31
    "https://indiankanoon.org/doc/981147/",  # Artcle 32
    "https://indiankanoon.org/doc/829916/", # Article 33
    "https://indiankanoon.org/doc/846153/", # Article 34
    "https://indiankanoon.org/doc/448465/", # Article 35
    "https://indiankanoon.org/doc/784506/", # Article 36
    "https://indiankanoon.org/doc/76375/",  # Article 37 - Not extracted
    "https://indiankanoon.org/doc/1673816/", # Article 38
    "https://indiankanoon.org/doc/555882/", # Article 39 - Not extracted
    "https://indiankanoon.org/doc/1714884/", # Article 40 - Not extracted
]

results = []

for url in article_urls:
    print(f"🔍 Scraping: {url}")
    data = scrape_constitution_article(url)
    if data:
        results.append(data)
    time.sleep(1)  # polite delay
# Out:
# 🔍 Scraping: https://indiankanoon.org/doc/367586/
# 🔍 Scraping: https://indiankanoon.org/doc/609295/
# 🔍 Scraping: https://indiankanoon.org/doc/211089/
# 🔍 Scraping: https://indiankanoon.org/doc/1987997/
# 🔍 Scraping: https://indiankanoon.org/doc/1163710/
# 🔍 Scraping: https://indiankanoon.org/doc/1218090/
# 🔍 Scraping: https://indiankanoon.org/doc/655638/
# 🔍 Scraping: https://indiankanoon.org/doc/1199182/
# 🔍 Scraping: https://indiankanoon.org/doc/581566/
# 🔍 Scraping: https://indiankanoon.org/doc/1071750/
# 🔍 Scraping: https://indiankanoon.org/doc/1540780/
# 🔍 Scraping: https://indiankanoon.org/doc/631708/
# 🔍 Scraping: https://indiankanoon.org/doc/1858991/
# 🔍 Scraping: https://indiankanoon.org/doc/211413/
# 🔍 Scraping: https://indiankanoon.org/doc/1734560/
# 🔍 Scraping: https://indiankanoon.org/doc/1734560/
# 🔍 Scraping: https://indiankanoon.org/doc/1983234/
# 🔍 Scraping: https://indiankanoon.org/doc/354224/
# 🔍 Scraping: https://indiankanoon.org/doc/981147/
# 🔍 Scraping: https://indiankanoon.org/doc/829916/
# 🔍 Scraping: https://indiankanoon.org/doc/846153/
# 🔍 Scraping: https://indiankanoon.org/doc/448465/
# 🔍 Scraping: https://indiankanoon.org/doc/784506/
# 🔍 Scraping: https://indiankanoon.org/doc/76375/
# 🔍 Scraping: https://indiankanoon.org/doc/1673816/
# 🔍 Scraping: https://indiankanoon.org/doc/555882/
# ❌ Failed to access https://indiankanoon.org/doc/555882/
# 🔍 Scraping: https://indiankanoon.org/doc/1714884/
# ❌ Failed to access https://indiankanoon.org/doc/1714884/

# %%
# Converting list to data frame and seeing the result
df = pd.DataFrame(results)
df.to_csv("constitution_articles.csv", index=False, encoding="utf-8-sig")

# print("✅ Saved all articles successfully to constitution_articles.csv")
df.head(25)
# Out:
#                                       url  \
# 0    https://indiankanoon.org/doc/367586/
# 1    https://indiankanoon.org/doc/609295/
# 2    https://indiankanoon.org/doc/211089/
# 3   https://indiankanoon.org/doc/1987997/
# 4   https://indiankanoon.org/doc/1163710/
# 5   https://indiankanoon.org/doc/1218090/
# 6    https://indiankanoon.org/doc/655638/
# 7   https://indiankanoon.org/doc/1199182/
# 8    https://indiankanoon.org/doc/581566/
# 9   https://indiankanoon.org/doc/1071750/
# 10  https://indiankanoon.org/doc/1540780/
# 11   https://indiankanoon.org/doc/631708/
# 12  https://indiankanoon.org/doc/1858991/
# 13   https://indiankanoon.org/doc/211413/
# 14  https://indiankanoon.org/doc/1734560/
# 15  https://indiankanoon.org/doc/1734560/
# 16  https://indiankanoon.org/doc/1983234/
# 17   https://indiankanoon.org/doc/354224/
# 18   https://indiankanoon.org/doc/981147/
# 19   https://indiankanoon.org/doc/829916/
# 20   https://indiankanoon.org/doc/846153/
# 21   https://indiankanoon.org/doc/448465/
# 22   https://indiankanoon.org/doc/784506/
# 23    https://indiankanoon.org/doc/76375/
# 24  https://indiankanoon.org/doc/1673816/
#
#                                   title  \
# 0   Article 14 in Constitution of India
# 1   Article 15 in Constitution of India
# 2   Article 16 in Constitution of India
# 3   Article 17 in Constitution of India
# 4   Article 18 in Constitution of India
# 5   Article 19 in Constitution of India
# 6   Article 20 in Constitution of India
# 7   Article 21 in Constitution of India
# 8   Article 22 in Constitution of India
# 9   Article 23 in Constitution of India
# 10  Article 24 in Constitution of India
# 11  Article 25 in Constitution of India
# 12  Article 26 in Constitution of India
# 13  Article 27 in Constitution of India
# 14  Article 28 in Constitution of India
# 15  Article 28 in Constitution of India
# 16  Article 30 in Constitution of India
# 17  Article 31 in Constitution of India
# 18  Article 32 in Constitution of India
# 19  Article 33 in Constitution of India
# 20  Article 34 in Constitution of India
# 21  Article 35 in Constitution of India
# 22  Article 36 in Constitution of India
# 23  Article 37 in Constitution of India
# 24  Article 38 in Constitution of India
#
#                                               content
# 0
# 1   (1) The State shall not discriminate against a...
# 2   (1) There shall be equality of opportunity for...
# 3
# 4   (1) No title, not being a military or academic...
# 5   (1) All citizens shall have the right- (a) to ...
# 6   (1) No person shall be convicted of any offenc...
# 7
# 8   (1) No person who is arrested shall be detaine...
# 9   (1) Traffic in human beings and beggar and oth...
# 10
# 11  (1) Subject to public order, morality and heal...
# 12
# 13
# 14  (1) No religious instruction shall be provided...
# 15  (1) No religious instruction shall be provided...
# 16  (1) All minorities, whether based on religion ...
# 17  (1) No person shall be deprived of his propert...
# 18  (1) The right to move the Supreme Court by app...
# 19
# 20
# 21
# 22
# 23
# 24  (1) The State shall strive to promote the welf...

# %%
# 25 articles with title and url is complete
# Some of the content has not been displayed, probably they have dynamic HTML structure or some other class name.
